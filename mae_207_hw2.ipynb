# %% [markdown]
# # Assignment 2: Inverse kinematics of our leg
#
# Use this noteboook to document interacting with the robot class. The primary goal for this assignment is a video recording and plot rendering of your robot leg commanded to move along an *interesting* path (see the bat sign I chose in the readme page).
#
# __Deliverables__
# 1. Your leg.py file in the robot python module we are creating. The template provided has blank functions which need to be completed.
# 2. Two videos, a video of your robot tracing out your commanded trajectory (uploaded to youtube), and a gif of robot commanded trajectory (like on the readme page).
# 3. This notebook which you will use to send the move commands for the trajectory.
#
#
# Team #:
#
# Names:

# %% [markdown]
# # Getting started

# %%
# Import the robot class we are developing
import robot

# %%
# Make a new leg variable which is a robot.Leg class
leg = robot.Leg()
# Out:
# here2

# %%
leg.get_joint_pos()

#print('joint0: %f \t joint1: %f' % (leg.joint_0_pos, leg.joint_1_pos))
# Out:
# (-1, -1)

# %% [markdown]
# # Your code below!

# %%
leg.set_home()

# %%
tt = 14
xx = [-1.25305623471883,
-2.36552567237164,
-2.80562347188264,
-1.85207823960880,
-0.201711491442543,
0.715158924205378,
2.13325183374083,
2.85452322738386,
3.28239608801956,
3.25794621026895,
2.56112469437653,
1.82762836185819,
0.409535452322737,
-1.25305623471883]

yy = [17.9278728606357,
16.5097799511002,
14.9572127139364,
13.4902200488998,
13.1112469437653,
13.0867970660147,
13.3190709046455,
14.4070904645477,
15.4584352078240,
16.6564792176039,
17.7567237163814,
17.9034229828851,
18.2212713936430,
17.9278728606357
]

leg.move_trajectory(tt,xx,yy)
# Out:
# 7.98292773827072
# 7.81828758067908
# 7.65791420687353
# 7.50146370701451
# 7.34868811601041
# 7.19939681362410
# 7.05343583243589
# 6.91067592365868
# 6.77100526466306
# 6.63432478860384
# 6.50054507421342
# 6.36958420486332
# 6.24136625219010
# 6.11582017497677
# 5.99287900173796
# 5.87247921181181
# 5.75456025831232
# 5.63906419438818
# 5.52593537599982
# 5.41512022224861
# 5.30656701960184
# 5.20022576003043
# 5.09604800565717
# 4.99398677435650
# 4.89399644208236
# 4.79603265867982
# 4.70005227466199
# 4.60601327698121
# 4.51387473223532
# 4.42359673606837
# 4.33514036776820
# 4.24846764925611
# 4.16354150781074
# 4.08032574199001
# 3.99878499030652
# 3.91888470228894
# 3.84059111162222
# 3.76387121111040
# 3.68869272924383
# 3.61502410818786
# 3.54283448303693
# 3.47209366219980
# 3.40277210880163
# 3.33484092300381
# 3.26827182515595
# 3.20303713970531
# 3.13910977979888
# 3.07646323252102
# 3.01507154471639
# 2.95490930935424
# 2.89595165239455
# 2.83817422012120
# 2.78155316691148
# 2.72606514341341
# 2.67168728510638
# 2.61839720122246
# 2.56617296400812
# 2.51499309830737
# 2.46483657145057
# 2.41568278343221
# 2.36751155736509
# 2.32030313019701
# 2.27403814367842
# 2.22869763557046
# 2.18426303108286
# 2.14071613453248
# 2.09803912121421
# 2.05621452947516
# 2.01522525298574
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     242         try:
# --> 243             return self._assumptions[fact]
#     244         except KeyError:
#
# KeyError: 'zero'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-55f713ff9ee2> in <module>()
#      31 ]
#      32
# ---> 33 leg.move_trajectory(tt,xx,yy)
#
# ~\ODrive-master\tools\robot\leg.py in move_trajectory(self, tt, xx, yy)
#     212             ax=plt.subplot(1,1,1)
#     213             for i in range (tt):
# --> 214                 self.set_foot_pos(xx[i],yy[i])
#     215                 self.draw_leg(ax)
#     216
#
# ~\ODrive-master\tools\robot\leg.py in set_foot_pos(self, x, y)
#     182         # if simulating exit function
#     183         if self.simulate == True:
# --> 184             (theta_0,theta_1)=self.inverse_kinematics(x,y)
#     185             self.joint_0_pos=theta_0
#     186             self.joint_1_pos=theta_1
#
# ~\ODrive-master\tools\robot\leg.py in inverse_kinematics(self, x, y)
#     305             x0=l0/2+l1*cos(theta_0)+l2*cos(alpha_0)
#     306             y0=l1*sin(theta_0)+l2*sin(alpha_0)
# --> 307             J1=self.J.subs([(theta0_sym,theta_0),(theta1_sym,theta_1)])
#     308             J1=sympy.N(J1)
#     309             J_inv=J1.pinv()
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\matrices\common.py in subs(self, *args, **kwargs)
#    1802         Matrix([[x]])
#    1803         """
# -> 1804         return self.applyfunc(lambda x: x.subs(*args, **kwargs))
#    1805
#    1806     def trace(self):
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\matrices\common.py in applyfunc(self, f)
#    1545             raise TypeError("`f` must be callable.")
#    1546
# -> 1547         return self._eval_applyfunc(f)
#    1548
#    1549     def as_real_imag(self):
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\matrices\common.py in _eval_applyfunc(self, f)
#    1485
#    1486     def _eval_applyfunc(self, f):
# -> 1487         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1488         return out
#    1489
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\matrices\common.py in <listcomp>(.0)
#    1485
#    1486     def _eval_applyfunc(self, f):
# -> 1487         out = self._new(self.rows, self.cols, [f(x) for x in self])
#    1488         return out
#    1489
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\matrices\common.py in <lambda>(x)
#    1802         Matrix([[x]])
#    1803         """
# -> 1804         return self.applyfunc(lambda x: x.subs(*args, **kwargs))
#    1805
#    1806     def trace(self):
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\basic.py in subs(self, *args, **kwargs)
#     914             rv = self
#     915             for old, new in sequence:
# --> 916                 rv = rv._subs(old, new, **kwargs)
#     917                 if not isinstance(rv, Basic):
#     918                     break
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1028         rv = self._eval_subs(old, new)
#    1029         if rv is None:
# -> 1030             rv = fallback(self, old, new)
#    1031         return rv
#    1032
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\basic.py in fallback(self, old, new)
#    1000                 if not hasattr(arg, '_eval_subs'):
#    1001                     continue
# -> 1002                 arg = arg._subs(old, new, **hints)
#    1003                 if not _aresame(arg, args[i]):
#    1004                     hit = True
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1028         rv = self._eval_subs(old, new)
#    1029         if rv is None:
# -> 1030             rv = fallback(self, old, new)
#    1031         return rv
#    1032
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\basic.py in fallback(self, old, new)
#    1000                 if not hasattr(arg, '_eval_subs'):
#    1001                     continue
# -> 1002                 arg = arg._subs(old, new, **hints)
#    1003                 if not _aresame(arg, args[i]):
#    1004                     hit = True
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\basic.py in _subs(self, old, new, **hints)
#    1028         rv = self._eval_subs(old, new)
#    1029         if rv is None:
# -> 1030             rv = fallback(self, old, new)
#    1031         return rv
#    1032
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\basic.py in fallback(self, old, new)
#    1005                     args[i] = arg
#    1006             if hit:
# -> 1007                 rv = self.func(*args)
#    1008                 hack2 = hints.get('hack2', False)
#    1009                 if hack2 and self.is_Mul and not rv.is_Mul:  # 2-arg hack
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     425
#     426         evaluate = options.get('evaluate', global_evaluate[0])
# --> 427         result = super(Function, cls).__new__(cls, *args, **options)
#     428         if not evaluate or not isinstance(result, cls):
#     429             return result
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     248
#     249         if evaluate:
# --> 250             evaluated = cls.eval(*args)
#     251             if evaluated is not None:
#     252                 return evaluated
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\functions\elementary\trigonometric.py in eval(cls, arg)
#     328             x, m = _peeloff_pi(arg)
#     329             if m:
# --> 330                 return sin(m)*cos(x) + cos(m)*sin(x)
#     331
#     332         if arg.func is asin:
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     425
#     426         evaluate = options.get('evaluate', global_evaluate[0])
# --> 427         result = super(Function, cls).__new__(cls, *args, **options)
#     428         if not evaluate or not isinstance(result, cls):
#     429             return result
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\function.py in __new__(cls, *args, **options)
#     248
#     249         if evaluate:
# --> 250             evaluated = cls.eval(*args)
#     251             if evaluated is not None:
#     252                 return evaluated
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\functions\elementary\trigonometric.py in eval(cls, arg)
#     530             return cls(-arg)
#     531
# --> 532         i_coeff = arg.as_coefficient(S.ImaginaryUnit)
#     533         if i_coeff is not None:
#     534             return cosh(i_coeff)
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\expr.py in as_coefficient(self, expr)
#    1499         """
#    1500
# -> 1501         r = self.extract_multiplicatively(expr)
#    1502         if r and not r.has(expr):
#    1503             return r
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\expr.py in extract_multiplicatively(self, c)
#    1985                 return x.extract_multiplicatively(b)
#    1986
# -> 1987         quotient = self / c
#    1988         if self.is_Number:
#    1989             if self is S.Infinity:
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\decorators.py in __sympifyit_wrapper(a, b)
#      89                 if not hasattr(b, '_op_priority'):
#      90                     b = sympify(b, strict=True)
# ---> 91                 return func(a, b)
#      92             except SympifyError:
#      93                 return retval
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\decorators.py in binary_op_wrapper(self, other)
#     130                     else:
#     131                         return f(self)
# --> 132             return func(self, other)
#     133         return binary_op_wrapper
#     134     return priority_decorator
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\expr.py in __div__(self, other)
#     158     @call_highest_priority('__rdiv__')
#     159     def __div__(self, other):
# --> 160         return Mul(self, Pow(other, S.NegativeOne))
#     161
#     162     @_sympifyit('other', NotImplemented)
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\operations.py in __new__(cls, *args, **options)
#      39             return args[0]
#      40
# ---> 41         c_part, nc_part, order_symbols = cls.flatten(args)
#      42         is_commutative = not nc_part
#      43         obj = cls._from_args(c_part + nc_part, is_commutative)
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\mul.py in flatten(cls, seq)
#     180                 a, b = b, a
#     181             assert not a is S.One
# --> 182             if not a.is_zero and a.is_Rational:
#     183                 r, b = b.as_coeff_Mul()
#     184                 if b.is_Add:
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in getit(self)
#     245             if self._assumptions is self.default_assumptions:
#     246                 self._assumptions = self.default_assumptions.copy()
# --> 247             return _ask(fact, self)
#     248
#     249     getit.func_name = as_property(fact)
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     300             continue
#     301         if pk in handler_map:
# --> 302             _ask(pk, obj)
#     303
#     304             # we might have found the value of fact
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\assumptions.py in _ask(fact, obj)
#     290         a = evaluate(obj)
#     291         if a is not None:
# --> 292             assumptions.deduce_all_facts(((fact, a),))
#     293             return a
#     294
#
# D:\Program Files (x86)\Anaconda3\lib\site-packages\sympy\core\facts.py in deduce_all_facts(self, facts)
#     535             for bidx in beta_maytrigger:
#     536                 bcond, bimpl = beta_rules[bidx]
# --> 537                 if all(self.get(k) is v for k, v in bcond):
#     538                     facts.append(bimpl)
#
# KeyboardInterrupt:

# %%
leg.inverse_kinematics(0,18)
